# %%
import sys; sys.path.append('../')

# %%
import torch

from helpers.sentinel import Bands
from helpers.image import plot_patch

# %%
patch_10m = torch.load('patch_10m.pt')
patch_20m = torch.load('patch_20m.pt')

# %%
plot_patch(patch_10m, Bands.m10.value)
plot_patch(patch_20m, Bands.m20.value)
